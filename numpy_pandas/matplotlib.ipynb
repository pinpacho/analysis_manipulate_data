# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt


# Grafico de lineas

month = np.array(['E','F','M','A','J'])
sales = np.array([2500,3000,2800,3500,4000])

plt.figure(figsize=(10,6))
plt.plot(month, sales, color='purple', marker='o', linestyle='--')
plt.title('Ventas mensuales de un producto')
plt.xlabel('Meses')
plt.ylabel('Ventas en USD')
plt.show()

# %%
#Grafico de dispersion es un tipo de grafico que muestra la relacion entre dos variables cuantitativas

#Tamaño del grafico
plt.figure(figsize=(8,6))
hours = [2,3,4,5,6,7,8]
exam_scores = [55,60,65,70,40,80,85]
plt.scatter(hours, exam_scores, color='green', marker='x')
plt.title('Relación entre horas de estudio y puntajes de exámenes')
plt.xlabel('Horas de estudio')
plt.ylabel('Puntajes de exámenes')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Grafico de dispersion es un tipo de grafico que muestra la relacion entre dos variables cuantitativas
#De dos estudiantes
#Tamaño del grafico
plt.figure(figsize=(8,6))
hours = [2,3,4,5,6,7,8]
exam_scores_1 = [55,60,65,70,40,80,85]

exam_scores_2 = [53,86,45,70,75,90,100]

#Grafico de dos estudiantes de dispersion

plt.scatter(hours, exam_scores_1, color='green', marker='x',linestyle='-',label='Estudiante 1')
plt.scatter(hours, exam_scores_2, color='blue', marker='s',linestyle='--',label='Estudiante 2')
plt.legend()
plt.title('Relación entre horas de estudio y puntajes de exámenes de dos estudiantes')
plt.xlabel('Horas de estudio')
plt.ylabel('Puntajes de exámenes')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Grafico de dispersion es un tipo de grafico que muestra la relacion entre dos variables cuantitativas
#De dos estudiantes
#Tamaño del grafico
plt.figure(figsize=(8,6))
hours = [2,3,4,5,6,7,8]
exam_scores_1 = [55,60,65,70,40,80,85]

exam_scores_2 = [53,86,45,70,75,90,100]

#Grafico de dos estudiantes de dispersion

plt.plot(hours, exam_scores_1, color='green', marker='x',linestyle='-',label='Estudiante 1')
plt.plot(hours, exam_scores_2, color='blue', marker='s',linestyle='--',label='Estudiante 2')
plt.legend()
plt.title('Relación entre horas de estudio y puntajes de exámenes de dos estudiantes')
plt.xlabel('Horas de estudio')
plt.ylabel('Puntajes de exámenes')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Barras y Pastel

# %%
# Grafico de barras es un tipo de grafico que representa datos categóricos con barras rectangulares cuya altura es proporcional al valor que representan.

plt.figure(figsize=(10,6))
categorias = ['A', 'B', 'C', 'D', 'E']
valores = [23, 45, 56, 78, 12]
plt.bar(categorias, valores, color='red',label='Valores por categoría')

#Destacar un punto específico
plt.annotate('Valor más alto', xy=('D', 78), xytext=('E', 80),
             arrowprops=dict(facecolor='black', shrink=0.05))

plt.legend()
plt.title('Gráfico de Barras de Categorías')
plt.xlabel('Categorías')
plt.ylabel('Valores')
plt.show()

# %%
#Barras horizontales
plt.figure(figsize=(10,6))
plt.barh(categorias, valores, color='orange',label='Valores por categoría')
plt.legend()
plt.title('Gráfico de Barras de Categorías')
plt.xlabel('Categorías')
plt.ylabel('Valores')
plt.show()

# %%
# Graficos de pastel son una representación gráfica de datos en forma de un círculo dividido en sectores, donde cada sector representa una proporción del total.
plt.pie(valores, labels=categorias, autopct='%1.1f%%', startangle=140, colors=['gold', 'lightblue', 'lightgreen', 'lightcoral', 'lavender'])
plt.title('Distribución de Valores por Categoría')
plt.show()

# %% [markdown]
# # Histogramas y Boxplots

# %%
# Los histogramas son una representación gráfica de la distribución de un conjunto de datos continuos, mostrando la frecuencia de los valores en intervalos específicos llamados "bins".

data = np.random.normal(170,10,200)
print(data)
# Out:
# [156.93473148 186.5813068  168.81835955 163.19821796 176.66383082
#  165.39280213 156.65741529 156.53282494 176.93773153 168.40426562
#  168.6629844  180.77743806 158.73174191 162.69322247 166.15120191
#  170.94351589 169.57828549 167.13112808 169.38373598 168.92694724
#  162.80395611 161.87007011 172.74516358 161.09084917 158.42644741
#  166.87707749 168.42332984 192.56723497 162.95299724 179.43260725
#  177.47188334 158.11055045 177.73252977 158.1611936  143.40827762
#  176.06319524 152.44109417 174.50934462 163.15989102 186.59550796
#  180.68509399 165.46614196 163.12162389 157.85922597 165.59077368
#  167.19644505 166.35306456 171.56703855 175.78521498 173.49654457
#  162.35856076 155.62208526 183.64531848 163.10550815 163.477064
#  164.78810688 151.5693045  165.22025996 165.20344186 176.20358298
#  176.98457149 170.03770889 179.31848374 173.39964984 169.84317888
#  171.60928168 168.09346506 166.05150486 167.32266463 158.71988669
# ...

# %%
plt.figure(figsize=(10,6))
plt.hist(data, bins=20, color='salmon', edgecolor='black', alpha=0.5)
plt.title('Histograma de Alturas')
plt.xlabel('Altura (cm)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Los boxplots, también conocidos como diagramas de caja, son una representación gráfica que muestra la distribución de un conjunto de datos a través de sus cuartiles, destacando la mediana, los valores atípicos y la dispersión de los datos.

np.random.seed(0)

ages = [np.random.normal(30,5,100),np.random.normal(40,7,100), np.random.normal(50,6,100)]

# %%
plt.figure(figsize=(8,6))
plt.boxplot(ages, vert=True, patch_artist=True, notch=True,label=['Grupo 1','Grupo 2','Grupo 3'])
plt.title('Boxplot de Edades por Grupo')
plt.xlabel('Grupos')
plt.ylabel('Edades')
plt.show()

# %% [markdown]
# # Visualización de Series Temporales

# %%
import pandas as pd

# Visualización de Series Temporales

from matplotlib.dates import DateFormatter

dates = pd.date_range(start= '2023-01-01',periods=100)

values = np.random.rand(100).cumsum()

data = pd.DataFrame({'Fecha':dates , 'Valor':values})

# %%
# Grafico de lineas

fig , ax = plt.subplots(figsize = (12,6))

ax.plot(data['Fecha'], data['Valor'], color='teal', linestyle='-')

plt.xticks(rotation = 45)
plt.title('Serie de Tiempo con formato en las fechas')
plt.xlabel('Fecha')
plt.ylabel('Valor')
# Out:
# Text(0, 0.5, 'Valor')

# %%
dates = pd.date_range(start= '2023-01-01',periods=12,freq='M')
sales = np.random.randint(1000,5000,12)

sales_data = pd.DataFrame({'Fecha':dates , 'Ventas':sales})

plt.plot(sales_data['Fecha'],sales_data['Ventas'], marker='o', color='purple', linestyle='-',label='Ventas Mensuales')

plt.gca().xaxis.set_major_formatter(DateFormatter('%b %Y'))

plt.xticks(rotation=45)
plt.title('Ventas Mensuales')
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_42168/288400801.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start= '2023-01-01',periods=12,freq='M')

# %% [markdown]
# # Multiples Graficos

# %%
import matplotlib.gridspec as gridspec

x = np.linspace(0,10,100)
y1 = np.sin(x)

data = np.random.randn(100)

# %%
gs = gridspec.GridSpec(2,2,height_ratios=[2,1],width_ratios=[1,1])#Esto hace que la 
#primera fila sea el doble de alta que la segunda y ambas columnas tengan el mismo ancho.

fig = plt.figure(figsize=(10,8))

# Primer Subplot, Ocupa la primera fila

ax1 = fig.add_subplot(gs[0,:])
ax1.plot(x,y1,color = 'blue')
ax1.set_title('Gráfico de Seno')
ax1.set_xlabel('X')
ax1.set_ylabel('sin(X)')

# Segundo subplot, fila 2 columna 1, esquina inferior izquierda

ax2 = fig.add_subplot(gs[1,0])
ax2.hist(data,bins=15,color='green',edgecolor='black',alpha=0.7)
ax2.set_title('Histograma')
ax2.set_xlabel('Valor')
ax2.set_ylabel('Frecuencia')

# Tercer Subplot , esquina inferior derecha

ax3 = fig.add_subplot(gs[1,1])
ax3.scatter(x, y1, color='red', alpha=0.5)
ax3.set_title('Gráfico de Dispersión')
ax3.set_xlabel('X')
ax3.set_ylabel('sin(X)')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Seaborn

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.barplot(x = ['A','B','C','D'], y = [5,7,3,4], palette='pastel')
# Out:
# /tmp/ipykernel_42168/3685172036.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = ['A','B','C','D'], y = [5,7,3,4], palette='pastel')
# <Axes: >

# %%
sns.set(style='dark',font='serif',font_scale=2)
sns.barplot(x = ['A','B','C','D'], y = [5,7,3,4], palette='pastel')
# Out:
# /tmp/ipykernel_42168/4081034719.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = ['A','B','C','D'], y = [5,7,3,4], palette='pastel')
# <Axes: >

# %%
tip = sns.load_dataset('tips')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(data=tip, x ='total_bill')
plt.show()

# %%
sns.displot(data=tip, x ='total_bill', y='tip',hue='sex')
plt.show()

# %%
sns.displot(data=tip, x ='total_bill', y='tip',hue='sex',kind='kde',legend=True,palette='dark',alpha=0.70)
plt.show()

# %%
sns.histplot(tip, x = 'tip',bins=20,cumulative=False,hue='sex',stat='density',multiple='dodge')
plt.show()

# %%
sns.kdeplot(tip,x='tip',hue='sex',shade=True)
plt.show()
# Out:
# /tmp/ipykernel_42168/361177593.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tip,x='tip',hue='sex',shade=True)

# %%
# Categoricos

sns.countplot(data=tip, x ='day', hue='sex')
plt.show()

# %%
sns.stripplot(data=tip, x='day', y='total_bill', hue='sex', dodge=True, palette='Set2')
plt.show()

# %%
sns.violinplot(data=tip, x='day', y='total_bill', hue='sex', split=True, palette='Set3')
plt.show()

# %%
sns.catplot(data=tip, x='day', y='total_bill', hue='sex', palette='Set1', height=6, aspect=1.5,kind='violin',col='time')
plt.show()

# %%
sns.scatterplot(data=tip,x='total_bill',y='tip',hue='day',style='time',size='size')
plt.legend(loc='center',bbox_to_anchor=[1.4,0.5])
plt.show()

# %%
markwers ={"Lunch":"D", "Dinner":"s"}
sns.scatterplot(data=tip,x='total_bill',y='tip',hue='day',style='time',size='size',markers=markwers)
plt.legend(loc='center',bbox_to_anchor=[1.4,0.5])
plt.show()

# %%
sns.relplot(data=tip,x='total_bill',y='tip',hue='day',style='time',size='size',markers=markwers)
plt.show()

# %%
#Joinplots

sns.jointplot(data=tip,x='total_bill',y='tip',hue='sex',kind='hist',marginal_ticks=True)
plt.show()

# %%
sns.pairplot(tip,hue='sex',palette='coolwarm',corner=True)
plt.show()

# %%
#Heatmap es una representación gráfica de datos en forma 
# de matriz, donde los valores individuales se 
# representan mediante colores, lo que facilita 
# la visualización de patrones, tendencias y 
# relaciones en conjuntos de datos complejos.

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
